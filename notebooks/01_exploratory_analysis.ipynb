# %% [markdown]
# # Exploratory analysis
# This notebook demonstrates the public synthetic ticket workflow. Run the data generator first if `data/synthetic_tickets.csv` does not exist.

# %%
from pathlib import Path
import pandas as pd

path = Path('../data/synthetic_tickets.csv')
df = pd.read_csv(path)
df.head()

# %%
df['priority'].value_counts(normalize=True).sort_index()

# %%
df.groupby('priority')['affected_users'].median()

# %% [markdown]
# ## Leakage note
# Only fields available at initial triage time are used for modeling. Resolution outcomes, resolver group, SLA breach status, and manual overrides are excluded.
